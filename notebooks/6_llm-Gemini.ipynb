# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext lab_black
# or nb_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %% [markdown]
# # Test Gemini AI

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What else would you buy together in a bundle product basket, if you have already bought and apple and a screw drive?",
)

print(response.text)
# Out:
# That's a wonderfully eclectic combination! An apple and a screwdriver don't typically go together, which means we have to get creative with the "bundle product basket" concept. We can approach this from a few angles: a practical "starter" kit, a themed "quirky" gift, or a more generalized "convenience" bundle.
#
# Here are a few ideas for what else you might buy together, depending on the *implied scenario* for buying an apple and a screwdriver:
#
# ---
#
# **Scenario 1: The "New Homeowner/First Apartment/Basic Essentials" Bundle**
# *(You're buying basic tools for assembling things and basic sustenance.)*
#
# *   **Apple** (healthy snack, quick energy)
# *   **Screwdriver** (for assembling furniture, tightening loose screws)
# *   **Additions:**
#     1.  **Small Hammer:** Essential for hanging pictures, light repairs.
#     2.  **Box of Assorted Screws/Nails:** To go with the screwdriver and hammer.
#     3.  **Measuring Tape:** Crucial for any DIY project or furniture placement.
#     4.  **Utility Knife / Box Cutter:** Opening packages, general cutting tasks.
#     5.  **Small First-Aid Kit:** For inevitable DIY mishaps (cuts, splinters).
#     6.  **Granola Bars / Trail Mix:** More non-perishable, quick energy snacks.
#     7.  **Water Bottle:** Stay hydrated while working.
#     8.  **Trash Bags:** Always needed, especially when moving or doing projects.
#
# ---
#
# **Scenario 2: The "On-the-Go / Emergency Kit" Bundle**
# *(You need a quick fix and a quick snack, perhaps in a car or a grab-and-go situation.)*
#
# *   **Apple** (fresh snack)
# *   **Screwdriver** (for minor roadside fixes, battery compartment issues, etc.)
# *   **Additions:**
#     1.  **Small Flashlight / Headlamp:** For working in low light.
#     2.  **Duct Tape (travel size roll):** The ultimate temporary fix-all.
#     3.  **Zip Ties:** Handy for securing loose items.
#     4.  **Wet Wipes / Hand Sanitizer:** Clean up after the fix or before eating.
#     5.  **Portable Phone Charger (Power Bank):** Always good to have power.
#     6.  **Protein Bar / Jerky:** More substantial, non-perishable food.
#     7.  **Small Rag / Microfiber Cloth:** For wiping surfaces or tools.
#
# ---
#
# **Scenario 3: The "Quirky & Practical Gift Basket" Bundle**
# *(Embracing the randomness, making it a fun, slightly ironic gift.)*
#
# *   **Apple** (the "healthy choice" ironically next to a tool)
# *   **Screwdriver** (the "handy solution")
# *   **Additions:**
#     1.  **Apple Corer / Slicer:** To prepare the apple perfectly.
#     2.  **Small Tool Box / Pouch:** To keep the screwdriver and other small tools organized.
#     3.  **A "How To" Book for Basic Home Repairs:** For the new DIYer.
#     4.  **A Craft Beer / Fancy Coffee Bag:** For relaxation after a "hard day's work."
#     5.  **A Humorous Greeting Card:** Explaining the "bundle of essentials for life's little twists and turns."
#     6.  **A Seed Packet (e.g., Apple seeds or a small herb):** To "plant new beginnings" (playing on the apple theme).
#
# ---
#
# **Scenario 4: The "Tech Repair & Snack Break" Bundle**
# *(You're fixing electronics and need a brain boost.)*
#
# *   **Apple** (healthy brain food)
# *   **Precision Screwdriver Set** (assuming a specific type for electronics)
# *   **Additions:**
#     1.  **Anti-Static Wrist Strap:** Essential for safe electronics repair.
#     2.  **Small Parts Organizer Tray:** To keep tiny screws and components from getting lost.
#     3.  **Magnetic Mat:** Keeps screws in place.
#     4.  **Tweezers / Pliers (small set):** For handling small components.
#     5.  **Compressed Air Duster:** To clean out dust from electronics.
#     6.  **Cable Ties / Velcro Straps:** For cable management after the fix.
#
# ---
#
# The beauty of a "bundle product basket" is that it can solve a *perceived* need, even if that need is a bit unusual. Given an apple and a screwdriver, the key is to imagine the *context* in which those two items were purchased.
