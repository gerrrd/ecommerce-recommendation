# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext lab_black
# or nb_black

# %% [markdown]
# # Test Gemini AI

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What else would you buy together in a bundle product basket, if you have already bought and apple and a screw drive?",
)

print(response.text)
# Out:
# That's a wonderfully eclectic starting point! An apple (food, healthy snack) and a screwdriver (tool, DIY, repair) don't naturally go together. This means we have to think about either:
#
# 1.  **The "Who"**: Who would buy both? (Likely *everyone* at some point – a general consumer, homeowner, student, someone moving).
# 2.  **The "When/Where"**: Where would they buy both? (A large general merchandise store like Walmart or Target, or online like Amazon).
# 3.  **The "Why"**: What common *needs* do these items represent, even if disparate? (Nourishment, maintenance, basic living).
#
# Given the disparity, the best approach is to consider **general household essentials, convenience, or items that support basic living/maintenance and snack needs.**
#
# Here are some bundle product basket ideas, categorized by rationale:
#
# ---
#
# **Option 1: The "New Homeowner/Basic Living Starter" Bundle**
# *(Focus: Essentials for moving in, general upkeep, and daily life)*
#
# *   **Paring Knife / Small Utility Knife:** For peeling/slicing the apple, opening boxes, or other small tasks where a screwdriver isn't suitable.
# *   **Small Cutting Board:** Perfect for the apple, but also handy for other small kitchen tasks or craft projects.
# *   **Assorted Screw/Nail Kit:** A screwdriver is useless without something to screw! A small multi-size kit is incredibly useful.
# *   **Tape Measure:** Essential for any DIY task, hanging pictures, or furniture assembly.
# *   **Small Hammer:** Another fundamental tool for basic household tasks (hanging pictures, light repairs).
# *   **Super Glue / Duct Tape:** The ultimate quick-fix solutions for a multitude of small problems.
# *   **Batteries (AA/AAA multi-pack):** Because *something* always needs batteries.
# *   **Reusable Shopping Bag:** For all those new essentials bought!
# *   **Snack Variety Pack (e.g., granola bars, nuts):** If you're buying an apple, you likely appreciate snacks. This offers variety and quick energy during DIY.
#
# ---
#
# **Option 2: The "Practical & Sustaining DIYer" Bundle**
# *(Focus: Supporting light DIY work while also providing sustenance and hygiene)*
#
# *   **Another Piece of Fruit (e.g., Banana or Orange):** Continues the healthy snack theme for sustained energy.
# *   **Water Bottle:** Stay hydrated while working on projects or just through the day.
# *   **Hand Wipes / Hand Sanitizer:** Clean up after using tools, before eating your apple.
# *   **Headlamp or Small LED Flashlight:** For working in dimly lit areas or during power outages.
# *   **Small Level:** For hanging shelves or pictures perfectly straight.
# *   **Small First-Aid Kit:** Because minor cuts and scrapes can happen during DIY.
#
# ---
#
# **Option 3: The "General Household Utility" Bundle**
# *(Focus: Random but universally useful items that fit a diverse shopping cart)*
#
# *   **Box Cutter / Utility Blade:** Opening packages, cutting string, general utility.
# *   **Paper Towels / Cleaning Wipes:** Accidents and messes happen, in the kitchen or during DIY.
# *   **All-Purpose Cleaner Spray:** For quick clean-ups around the house.
# *   **Light Bulbs (multi-pack):** Something everyone eventually needs.
# *   **Trash Bags (small roll):** Essential for kitchen and general disposal.
#
# ---
#
# **Which one is best?**
#
# The **"New Homeowner/Basic Living Starter" Bundle** is probably the strongest as it blends basic kitchen utility (for the apple) with fundamental tool utility (for the screwdriver) and general household preparedness. It assumes a broad consumer looking for efficiency and value.
