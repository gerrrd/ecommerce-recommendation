# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext nb_black

# %% [markdown]
# # Imports and functions
#
# This file is to test the functionalities of the API

# %%
import requests
import json

# %%
url = "http://0.0.0.0:8080/predict"

# %%
def call_and_print(input_request: dict):
    data_json = json.dumps(input_request)
    response = requests.post(url, data=data_json)
    print(json.dumps(response.json(), indent=4))

# %% [markdown]
# # Tests

# %% [markdown]
# ## Association rules
#
# Based on a selected set of product(s) `List[int]`

# %%
input_request = {
    "recommender_model": "association_rules",
    "selected_products": [4, 5]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "association_rules",
#         "customer_id": -1,
#         "selected_products": [
#             4,
#             5
#         ],
#         "description": ""
#     },
#     "output": [],
#     "estimation_id": "de71cf94-8565-43e1-9295-bfdd78d38e4f",
#     "processing_time": 0
# }

# %%
input_request = {
    "recommender_model": "association_rules",
    "selected_products": [10123]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "association_rules",
#         "customer_id": -1,
#         "selected_products": [
#             10123
#         ],
#         "description": ""
#     },
#     "output": [],
#     "estimation_id": "f2a40b89-eb54-49a5-85de-4320556d43c8",
#     "processing_time": 0
# }

# %%
input_request = {
    "recommender_model": "association_rules",
    "selected_products": [22916]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "association_rules",
#         "customer_id": -1,
#         "selected_products": [
#             22916
#         ],
#         "description": ""
#     },
#     "output": [
#         22917,
#         22918,
#         22920,
#         22919
#     ],
#     "estimation_id": "ccc09f16-c134-4baf-bf6d-2c579a0b3dd5",
#     "processing_time": 0
# }

# %%
input_request = {
    "recommender_model": "association_rules",
    "selected_products": [22916, 22554]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "association_rules",
#         "customer_id": -1,
#         "selected_products": [
#             22916,
#             22554
#         ],
#         "description": ""
#     },
#     "output": [
#         22917,
#         22918,
#         22920,
#         22919,
#         22551
#     ],
#     "estimation_id": "b13cee5e-a14a-4cf8-93c4-c255d2699dc1",
#     "processing_time": 0
# }

# %% [markdown]
# ## Collaborative filtering
#
# Based on a customerId, if known, if not: set of product(s) `List[int]`

# %%
input_request = {
    "recommender_model": "collaborative_filtering",
    "customer_id": 	14688,
    "selected_products": []
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "collaborative_filtering",
#         "customer_id": 14688,
#         "selected_products": [],
#         "description": ""
#     },
#     "output": [
#         23206,
#         22383,
#         23208,
#         21213,
#         23209
#     ],
#     "estimation_id": "b48447ce-7cd0-4ede-b26d-ef28f6c76e67",
#     "processing_time": 1
# }

# %%
input_request = {
    "recommender_model": "collaborative_filtering",
    "customer_id": 	-1,
    "selected_products": [71270, 21166]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "collaborative_filtering",
#         "customer_id": -1,
#         "selected_products": [
#             71270,
#             21166
#         ],
#         "description": ""
#     },
#     "output": [
#         21181,
#         21175,
#         22423,
#         21174,
#         85099
#     ],
#     "estimation_id": "674be56e-3f94-402c-89eb-bd6cfbd8a002",
#     "processing_time": 19
# }

# %% [markdown]
# ## Tf-idf
#
# Based on a selected set of product(s) `List[int]` or a Description `str`

# %%
input_request = {
    "recommender_model": "tfidf",
    "selected_products": [23295]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "tfidf",
#         "customer_id": -1,
#         "selected_products": [
#             23295
#         ],
#         "description": ""
#     },
#     "output": [
#         23296,
#         85187,
#         85197,
#         23293,
#         23294
#     ],
#     "estimation_id": "4678813b-e1ba-4894-8d6d-63996870bbc4",
#     "processing_time": 0
# }

# %%
input_request = {
    "recommender_model": "tfidf",
    "selected_products": [23295, 82484]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "tfidf",
#         "customer_id": -1,
#         "selected_products": [
#             23295,
#             82484
#         ],
#         "description": ""
#     },
#     "output": [
#         23296,
#         85187,
#         23113,
#         85197,
#         82482,
#         82483,
#         84884,
#         82486,
#         23293,
#         23294
#     ],
#     "estimation_id": "24ca280e-206e-43b8-aa38-b18db015a46e",
#     "processing_time": 0
# }

# %%
input_request = {
    "recommender_model": "tfidf",
    "selected_products": [],
    "description": "BLACK DESK LIGHT"
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "tfidf",
#         "customer_id": -1,
#         "selected_products": [],
#         "description": "BLACK DESK LIGHT"
#     },
#     "output": [
#         22929,
#         85116,
#         85118,
#         21814,
#         21815
#     ],
#     "estimation_id": "3ed3988f-421b-4e58-8bde-cbd140bb3a1a",
#     "processing_time": 0
# }

# %% [markdown]
# ## LLM
#
# Based on a selected set of product(s) `List[int]` or a Description `str` -- but it is not included in the API.
#
# All should give `[0]` as it is not implemented in the API

# %%
input_request = {
    "recommender_model": "llm",
    "selected_products": [23295, 82484]
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "llm",
#         "customer_id": -1,
#         "selected_products": [
#             23295,
#             82484
#         ],
#         "description": ""
#     },
#     "output": [
#         0
#     ],
#     "estimation_id": "4c27845e-8273-4db1-a71b-f38ead0f9a54",
#     "processing_time": 0
# }

# %%
input_request = {
    "recommender_model": "tfidf",
    "selected_products": [],
    "description": "BLACK DESK LIGHT"
}

call_and_print(input_request)
# Out:
# {
#     "input": {
#         "recommender_model": "tfidf",
#         "customer_id": -1,
#         "selected_products": [],
#         "description": "BLACK DESK LIGHT"
#     },
#     "output": [
#         22929,
#         85116,
#         85118,
#         21814,
#         21815
#     ],
#     "estimation_id": "8b51046e-e89f-41e5-8f99-62f113941775",
#     "processing_time": 0
# }
